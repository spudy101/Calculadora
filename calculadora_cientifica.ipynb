# %%
"""Para poder ejecutar este código es necesario Python 3.0 o superior, no vale Python 2.
Python 3 puede ser descargado mediante el enlace https://www.python.org/downloads y haciendo
click en una versión de Python 3"""
 
import math
import os
from tokenize import Double
#Aquí importamos las librerías
 
__author__ = "HDB PROGRAMMING"
 
def Menu():
 
    print("                     ÉÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍ»")
    print("                     º                                  :: C A L C U L A D O R A ::                                      º")
    print("                     ÌÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍ¹")
    print("                     º                                                                                                   º")
    print("                     º  1.- Sumar               2.- Restar             3.-Multiplicar              4.- Dividir           º")
    print("                     º                                                                                                   º")
    print("                     º  5.- Sacar Resto         6.- Sacar Potencia     7.- Sacar Raíz Cudrada      8.-  Sacar Seno       º")
    print("                     º                                                                                                   º")
    print("                     º  9.- Sacar Arcoseno      10.- Sacar Coseno      11.- Sacar Arcocoseno       12.- Sacar Tangente   º")
    print("                     º                                                                                                   º")
    print("                     º  13.- Sacar Arcotangnt   14.- Sacar M.C.M       15.- Sacar M.C.D            16.- Sacar Fibonacci  º")
    print("                     º                                                                                                   º")
    print("                     º  17.- Sacar Factorial    18.- Sacar Val. Abs.   19.- Versión                20.- Ayuda            º")
    print("                     º                                                                                                   º")
    print("                     º                          21.- Borr. Pant.       22.- Salir                                        º")
    print("                     º                                                                                                   º")
    print("                     ÈÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍ¼")
    print("")
 
def mcd(numero1, numero2):
    numero1 = max(numero1, numero2) 
    numero2 = min(numero1, numero2)
    while numero2!=0:
        mcd = numero2
        numero2 = numero1%numero2
        numero1 = mcd
    return mcd
 
def mcm(numero1, numero2):
    numero1 = max(numero1, numero2)
    numero2 = min(numero1, numero2)
    mcm = (numero1 / mcd(numero1, numero2)) * numero2
    return mcm
 
def borrarPantalla():
    if os.name == "posix":
        os.system ("clear")
    elif os.name == "ce" or os.name == "nt" or os.name == "dos":
        os.system ("cls")
 
def Calculadora():
 
    Menu()
 
    opciones = float(input("Seleccionar Nº de Opción: "))
 
    while (opciones >0 and opciones <24):
 
        if (opciones==1):
            print("")
            numero1 = float(input("Ingresar Primer Número: "))
            print("")
            numero2 = float(input("Ingresar Segundo Número: "))
            print("")
            print ('La Sumar es:', numero1+numero2)
            print("")
            Continuar = input("¿Desea Continuar con esta Opción?(S/N): ")
 
            if Continuar == "s" or Continuar == "S":
                opciones = 1
 
            elif Continuar == "n" or Continuar == "N":
                print("")
                opciones = float(input("Seleccionar Nº de Opción: "))
 
            else:
                print("")
                Continuar = input("Por Favor escoja(S/N): ")
 
                if Continuar == "s" or Continuar == "S":
                    opciones = 1
 
                elif Continuar == "n" or Continuar == "N":
                    print("")
                    opciones = float(input("Seleccionar Nº de Opción: "))
 
 
        elif(opciones==2):
            print("")
            numero1 = float(input("Ingresar Primer Número: "))
            print("")
            numero2 = float(input("Ingresar Segundo Número: "))
            print("")
            print ('La Restar es:',numero1-numero2)
            print("")
            Continuar = input("¿Desea Continuar con esta Opción?(S/N): ")
 
            if Continuar == "s" or Continuar == "S":
                opciones = 2
 
            elif Continuar == "n" or Continuar == "N":
                print("")
                opciones = float(input("Seleccionar Nº de Opción: "))
 
            else:
                print("")
                Continuar = input("Por Favor escoja(S/N): ")
 
                if Continuar == "s" or Continuar == "S":
                    opciones = 2
 
                elif Continuar == "n" or Continuar == "N":
                    print("")
                    opciones = float(input("Seleccionar Nº de Opción: "))
 
        elif(opciones==3):
            print("")
            numero1 = float(input("Ingresar Primer Número: "))
            print("")
            numero2 = float(input("Ingresar Segundo Número: "))
            print("")
            print ('La Multiplicación es:', numero1*numero2)
            print("")
            Continuar = input("¿Desea Continuar con esta Opción?(S/N): ")
 
            if Continuar == "s" or Continuar == "S":
                opciones = 3
 
            elif Continuar == "n" or Continuar == "N":
                print("")
                opciones = float(input("Seleccionar Nº de Opción: "))
 
            else:
                print("")
                Continuar = input("Por Favor escoja(S/N): ")
 
                if Continuar == "s" or Continuar == "S":
                    opciones = 3
 
                elif Continuar == "n" or Continuar == "N":
                    print("")
                    opciones = float(input("Seleccionar Nº de Opción: "))
 
        elif(opciones==4):
            print("")
            numero1 = float(input("Ingresar Primer Número: "))
            print("")
            numero2 = float(input("Ingresar Segundo Número: "))
            print("")
 
            try:
              print ('La División es:', numero1/numero2)
              print("")
              Continuar = input("¿Desea Continuar con esta Opción?(S/N): ")
 
              if Continuar == "s" or Continuar == "S":
                opciones = 4
 
              elif Continuar == "n" or Continuar == "N":
                print("")
                opciones = float(input("Seleccionar Nº de Opción: "))
 
              else:
                print("")
                Continuar = input("Por Favor escoja(S/N): ")
 
                if Continuar == "s" or Continuar == "S":
                    opciones = 4
 
                elif Continuar == "n" or Continuar == "N":
                    print("")
                    opciones = float(input("Seleccionar Nº de Opción: "))
 
            except ZeroDivisionError:
              print ('No se Permite la División Entre 0')
              print("")
              Continuar = input("¿Desea Continuar con esta Opción?(S/N): ")
 
              if Continuar == "s" or Continuar == "S":
                opciones = 4
 
              elif Continuar == "n" or Continuar == "N":
                print("")
                opciones = float(input("Seleccionar Nº de Opción: "))
 
              else:
                print("")
                Continuar = input("Por Favor escoja(S/N): ")
 
                if Continuar == "s" or Continuar == "S":
                    opciones = 4
 
                elif Continuar == "n" or Continuar == "N":
                    print("")
                    opciones = float(input("Seleccionar Nº de Opción: "))
 
        elif(opciones==5):
            print("")
            numero1 = float(input("Ingresar Primer Número: "))
            print("")
            while numero1<0:
                print("")
                print("Numeros negativos no son validos, ingrese un numero valido")
                numero1 = float(input("Ingrese Primer Número: "))
                print("")
            numero2 = float(input("Ingresar Segundo Número: "))
            print("")
            while numero2<0:
                print("")
                print("Numeros negativos no son validos, ingrese un numero valido")
                num2 = float(input("Ingrese Segundo Número: "))
                print("")
            print ('El Resto es:', numero1%numero2)
            print("")
            Continuar = input("¿Desea Continuar con esta Opción?(S/N): ")
 
            if Continuar == "s" or Continuar == "S":
                opciones = 5
 
            elif Continuar == "n" or Continuar == "N":
                print("")
                opciones = float(input("Seleccionar Nº de Opción: "))
 
            else:
                print("")
                Continuar = input("Por Favor escoja(S/N): ")
 
                if Continuar == "s" or Continuar == "S":
                    opciones = 5
 
                elif Continuar == "n" or Continuar == "N":
                    print("")
                    opciones = float(input("Seleccionar Nº de Opción: "))
 
        elif(opciones==6):
            print("")
            base = float(input("Ingresar Base: "))
            print("")
            exponente = float(input("Ingresar Exponente: "))
            print("")
            print('La Potencia es:', base**exponente)
            print("")
            Continuar = input("¿Desea Continuar con esta Opción?(S/N): ")
 
            if Continuar == "s" or Continuar == "S":
                opciones = 6
 
            elif Continuar == "n" or Continuar == "N":
                print("")
                opciones = float(input("Seleccionar Nº de Opción: "))
 
            else:
                print("")
                Continuar = input("Por Favor escoja(S/N): ")
 
                if Continuar == "s" or Continuar == "S":
                    opciones = 6
 
                elif Continuar == "n" or Continuar == "N":
                    print("")
                    opciones = float(input("Seleccionar Nº de Opción: "))
 
        elif(opciones==7):
            print("")
            numero = float(input("Ingresar Número: "))
            print("")
            while numero<0:
                print("")
                print("Numeros negativos no son validos, ingrese un numero valido")
                numero = float(input("Ingrese Número: "))
                print("")
            print("La raíz cuadrada de {} es {}".format(numero, math.sqrt(numero)))
            print("")
            Continuar = input("¿Desea Continuar con esta Opción?(S/N): ")
 
            if Continuar == "s" or Continuar == "S":
                opciones = 7
 
            elif Continuar == "n" or Continuar == "N":
                print("")
                opciones = float(input("Seleccionar Nº de Opción: "))
 
            else:
                print("")
                Continuar = input("Por Favor escoja(S/N): ")
 
                if Continuar == "s" or Continuar == "S":
                    opciones = 7
 
                elif Continuar == "n" or Continuar == "N":
                    print("")
                    opciones = float(input("Seleccionar Nº de Opción: "))
 
        elif(opciones==8):
            print("")
            radianes = float(input("Ingresar Radianes: "))
            print("")
            while radianes>1:
                print("")
                print("no se puede sacar un radian de numero superior a 1, ingrese un radian valido")
                radianes = float(input("Ingrese Radianes: "))
                print("")
            print("El seno de {} es {}".format(radianes, math.sin(radianes)))
            print("")
            Continuar = input("¿Desea Continuar con esta Opción?(S/N): ")
 
            if Continuar == "s" or Continuar == "S":
                opciones = 8
 
            elif Continuar == "n" or Continuar == "N":
                print("")
                opciones = float(input("Seleccionar Nº de Opción: "))
 
            else:
 
                print("")
                Continuar = input("Por Favor escoja(S/N): ")
 
                if Continuar == "s" or Continuar == "S":
                    opciones = 8
 
                elif Continuar == "n" or Continuar == "N":
                    print("")
                    opciones = float(input("Seleccionar Nº de Opción: "))
 
        elif(opciones==9):
            print("")
            radianes = float(input("Ingresar Radianes: "))
            print("")
            while radianes>1:
                print("")
                print("No se puede sacar un radian superior a 1")
                radianes = float(input("Ingresar Radianes: "))
                print("")
            print("El arcoseno de {} es {}".format(radianes, math.asin(radianes)))
            print("")
            Continuar = input("¿Desea Continuar con esta Opción?(S/N): ")
 
            if Continuar == "s" or Continuar == "S":
                opciones = 9
 
            elif Continuar == "n" or Continuar == "N":
                print("")
                opciones = float(input("Seleccionar Nº de Opción: "))
 
            else:
                print("")
                Continuar = input("Por Favor escoja(S/N): ")
 
                if Continuar == "s" or Continuar == "S":
                    opciones = 9
 
                elif Continuar == "n" or Continuar == "N":
                    print("")
                    opciones = float(input("Seleccionar Nº de Opción: "))
 
        elif(opciones==10):
            print("")
            radianes = float(input("Ingresar Radianes: "))
            print("")
            print("El coseno de {} es {}".format(radianes, math.cos(radianes)))
            print("")
            Continuar = input("¿Desea Continuar con esta Opción?(S/N): ")
 
            if Continuar == "s" or Continuar == "S":
                opciones = 10
 
            elif Continuar == "n" or Continuar == "N":
                print("")
                opciones = float(input("Seleccionar Nº de Opción: "))
 
            else:
                print("")
                Continuar = input("Por Favor escoja(S/N): ")
 
                if Continuar == "s" or Continuar == "S":
                    opciones = 10
 
                elif Continuar == "n" or Continuar == "N":
                    print("")
                    opciones = float(input("Seleccionar Nº de Opción: "))
 
        elif(opciones==11):
            print("")
            radianes = float(input("Ingresar Radianes: "))
            print("")
            while radianes<0:
                print("")
                print("Error Indefinido, ingrese un radian valido")
                radianes = float(input("Ingrese Radianes: "))
                print("")
            print("El arcocoseno de {} es {}".format(radianes, math.acos(radianes)))
            print("")
            Continuar = input("¿Desea Continuar con esta Opción?(S/N): ")
 
            if Continuar == "s" or Continuar == "S":
                opciones = 11
 
            elif Continuar == "n" or Continuar == "N":
                print("")
                opciones = float(input("Seleccionar Nº de Opción: "))
 
            else:
                print("")
                Continuar = input("Por Favor escoja(S/N): ")
 
                if Continuar == "s" or Continuar == "S":
                    opciones = 11
 
                elif Continuar == "n" or Continuar == "N":
                    print("")
                    opciones = float(input("Seleccionar Nº de Opción: "))
 
        elif(opciones==12):
            print("")
            radianes = float(input("Ingresar Radianes: "))
            print("")
            print("La tangente de {} es {}".format(radianes, math.tan(radianes)))
            print("")
            Continuar = input("¿Desea Continuar con esta Opción?(S/N): ")
 
            if Continuar == "s" or Continuar == "S":
                opciones = 12
 
            elif Continuar == "n" or Continuar == "N":
                print("")
                opciones = float(input("Seleccionar Nº de Opción: "))
 
            else:
                print("")
                Continuar = input("Por Favor escoja(S/N): ")
 
                if Continuar == "s" or Continuar == "S":
                    opciones = 12
 
                elif Continuar == "n" or Continuar == "N":
                    print("")
                    opciones = float(input("Seleccionar Nº de Opción: "))
 
        elif(opciones==13):
            centinella=True           
            while centinella:
                try:
                    print("")
                    radianes = int(input("Ingrese Radianes: "))
                    print("")
                    centinella=False
                except ValueError:
                    print("")
                    print("Error: Solo escriba numeros")                  

            print("La arcotangente de {} es {}".format(radianes, math.atan(radianes)))
            print("")
            Continuar = input("¿Desea Continuar con esta Opción?(S/N): ")
 
            if Continuar == "s" or Continuar == "S":
                opciones = 13
 
            elif Continuar == "n" or Continuar == "N":
                print("")
                opciones = float(input("Seleccionar Nº de Opción: "))
 
            else:
                print("")
                Continuar = input("Por Favor escoja(S/N): ")
 
                if Continuar == "s" or Continuar == "S":
                    opciones = 13
 
                elif Continuar == "n" or Continuar == "N":
                    print("")
                    opciones = float(input("Seleccionar Nº de Opción: "))
 
 
        elif(opciones==14):
            print("")
            numero1 = float(input("Ingresar Primer Número: "))
            print("")
            while numero1<0:
                print("")
                print("Numeros negativos no son validos, ingrese un numero valido")
                numero1 = float(input("Ingrese Primer Número: "))
                print("")
            numero2 = float(input("Ingresar Segundo Número: "))
            print("")
            while numero2<0:
                print("")
                print("Numeros negativos no son validos, ingrese un numero valido")
                numero2 = float(input("Ingrese Segundo Número: "))
                print("")
            print("El M.C.M. entre "+str(numero1)+" y "+str(numero2)+" es: "+str(mcm(numero1, numero2)))
            print("")
            Continuar = input("¿Desea Continuar con esta Opción?(S/N): ")
 
            if Continuar == "s" or Continuar == "S":
                opciones = 14
 
            elif Continuar == "n" or Continuar == "N":
                print("")
                opciones = float(input("Seleccionar Nº de Opción: "))
 
            else:
                print("")
                Continuar = input("Por Favor escoja(S/N): ")
 
                if Continuar == "s" or Continuar == "S":
                    opciones = 14
 
                elif Continuar == "n" or Continuar == "N":
                    print("")
                    opciones = float(input("Seleccionar Nº de Opción: "))
 
        elif(opciones==15):
            print("")
            numero1 = float(input("Ingresar Primer Número: "))
            print("")
            while numero1<0:
                print("")
                print("Numeros negativos no son validos, ingrese un numero valido")
                numero1 = float(input("Ingrese Primer Número: "))
                print("")
            numero2 = float(input("Ingresar Segundo Número: "))
            print("")
            while numero2<0:
                print("")
                print("Numeros negativos no son validos, ingrese un numero valido")
                numero2 = float(input("Ingrese Segundo Número: "))
                print("")
            print("El M.C.D. entre "+str(numero1)+" y "+str(numero2)+" es: "+str(mcd(numero1, numero2)))
            print("")
            Continuar = input("¿Desea Continuar con esta Opción?(S/N): ")
 
            if Continuar == "s" or Continuar == "S":
                opciones = 15
 
            elif Continuar == "n" or Continuar == "N":
                print("")
                opciones = float(input("Seleccionar Nº de Opción: "))
 
            else:
                print("")
                Continuar = input("Por Favor escoja(S/N): ")
 
                if Continuar == "s" or Continuar == "S":
                    opciones = 15
 
                elif Continuar == "n" or Continuar == "N":
                    print("")
                    opciones = float(input("Seleccionar Nº de Opción: "))
 
        elif(opciones==16):
            print("")
            fibonacci = []
            x = 1
            y = 0
            numero = int(input("Numero de elementos: "))
            print("")
            while numero<0:
                print("")
                print("Error, ingrese un número valido (positivo)")
                numero = int(input("Numero de elementos: "))
                print("")
            for n in range(numero):
                fibonacci.append(x + y)
                auxiliar = x + y
                x = y
                y = auxiliar
            print(fibonacci)
            print("")
            Continuar = input("¿Desea Continuar con esta Opción?(S/N): ")
 
            if Continuar == "s" or Continuar == "S":
                opciones = 16
 
            elif Continuar == "n" or Continuar == "N":
                print("")
                opciones = int(input("Seleccionar Nº de Opción: "))
 
            else:
                print("")
                Continuar = input("Por Favor escoja(S/N): ")
 
                if Continuar == "s" or Continuar == "S":
                    opciones = 16
 
                elif Continuar == "n" or Continuar == "N":
                    print("")
                    opciones = int(input("Seleccionar Nº de Opción: "))
 
        elif(opciones==17):
            print("")
            numero = float(input("Ingresar Número: "))
            print("")
            try:
                print("El factorial de {} es {}".format(numero, math.factorial(numero)))
                print("")
                Continuar = input("¿Desea Continuar con esta Opción?(S/N): ")
 
                if Continuar == "s" or Continuar == "S":
                    opciones = 17
 
                elif Continuar == "n" or Continuar == "N":
                    print("")
                    opciones = float(input("Seleccionar Nº de Opción: "))
 
                else:
                    print("")
                    Continuar = input("Por Favor escoja(S/N): ")
 
                    if Continuar == "s" or Continuar == "S":
                        opciones = 17
 
                    elif Continuar == "n" or Continuar == "N":
                        print("")
                        opciones = float(input("Seleccionar Nº de Opción: "))
 
            except ValueError:
                print("No se Admiten Números Negativos")
                print("")
                Continuar = input("¿Desea Continuar con esta Opción?(S/N): ")
 
                if Continuar == "s" or Continuar == "S":
                    opciones = 17
 
                elif Continuar == "n" or Continuar == "N":
                    print("")
                    opciones = float(input("Seleccionar Nº de Opción: "))
 
                else:
                    print("")
                    Continuar = input("Por Favor escoja(S/N): ")
 
                    if Continuar == "s" or Continuar == "S":
                        opciones = 17
 
                    elif Continuar == "n" or Continuar == "N":
                        print("")
                        opciones = float(input("Seleccionar Nº de Opción: "))
 
        elif(opciones==18):
            print("")
            numero = float(input("Ingresar Número: "))
            print("")
            print("El valor absoluto de {} es {}".format(numero, math.fabs(numero)))
            print("")
            Continuar = input("¿Desea Continuar con esta Opción?(S/N): ")
 
            if Continuar == "s" or Continuar == "S":
                opciones = 17
 
            elif Continuar == "n" or Continuar == "N":
                print("")
                opciones = float(input("Seleccionar Nº de Opción: "))
 
            else:
                print("")
                Continuar = input("Por Favor escoja(S/N): ")
 
                if Continuar == "s" or Continuar == "S":
                    opciones = 17
 
                elif Continuar == "n" or Continuar == "N":
                    print("")
                    opciones = float(input("Seleccionar Nº de Opción: "))
 
 
        elif(opciones==19):
            print("")
            print("Calculadora Python ver. 1.5.0.2")
            print("")
            opciones = float(input("Seleccionar Nº de Opción: "))
 
        elif(opciones==20):
            print("")
            print("    ==========================MENÚ DE AYUDA=============================")
            print("    |                                                                  |")
            print("    |   1.- Creador del Software       2.- ¿Cómo escojo una opción?    |")
            print("    |                                                                  |")
            print("    |                       3.- Licencia                               |")
            print("    |                                                                  |")
            print("    ====================================================================")
            print("")
            Ayuda_Opciones = float(input("Seleccionar Nº de Opción: "))
            while(Ayuda_Opciones > 0 and Ayuda_Opciones < 5):
                if(Ayuda_Opciones==1):
                    print("")
                    print("El creador de este programa es SOMEONE360 puede contactar con el mediante el correo tutiolinux@gmail.com")
                    print("")
                    Continuar = input("¿Desea Continuar con esta Opción?(S/N): ")
 
                    if Continuar == "s" or Continuar == "S":
                        print("")
                        Ayuda_Opciones = float(input("Seleccionar Nº de Opción: "))
 
                    elif Continuar == "n" or Continuar == "N":
                        print("")
                        opciones = float(input("Seleccionar Nº de Opción: "))
                        Ayuda_Opciones = 4
 
                    else:
                        print("")
                        Continuar = input("Por Favor escoja(S/N): ")
 
                        if Continuar == "s" or Continuar == "S":
                            print("")
                            Ayuda_Opciones = float(input("Seleccionar Nº de Opción: "))
 
                        elif Continuar == "n" or Continuar == "N":
                            print("")
                            opciones = float(input("Seleccionar Nº de Opción: "))
                            Ayuda_Opciones = 4
 
                elif(Ayuda_Opciones==2):
                    print("")
                    print("Debe seleccionar el numero de la opcion y pulsar Enter")
                    print("")
                    Continuar = input("¿Desea Continuar con esta Opción?(S/N): ")
 
                    if Continuar == "s" or Continuar == "S":
                        print("")
                        Ayuda_Opciones = float(input("Seleccionar Nº de Opción: "))
 
                    elif Continuar == "n" or Continuar == "N":
                        print("")
                        opciones = float(input("Seleccionar Nº de Opción: "))
                        Ayuda_Opciones = 4
 
                    else:
                        print("")
                        Continuar = input("Por Favor escoja(S/N): ")
 
                        if Continuar == "s" or Continuar == "S":
                            print("")
                            Ayuda_Opciones = float(input("Seleccionar Nº de Opción: "))
 
                        elif Continuar == "n" or Continuar == "N":
                            print("")
                            opciones = float(input("Seleccionar Nº de Opción: "))
                            Ayuda_Opciones = 4
 
                elif(Ayuda_Opciones==3):
                    print("")
                    print("Este programa puede ser editado o vendido sin ningun problema")
                    print("")
                    Continuar = input("¿Desea Continuar con esta Opción?(S/N): ")
 
                    if Continuar == "s" or Continuar == "S":
                        print("")
                        Ayuda_Opciones = float(input("Seleccionar Nº de Opción: "))
 
                    elif Continuar == "n" or Continuar == "N":
                        print("")
                        opciones = float(input("Seleccionar Nº de Opción: "))
                        Ayuda_Opciones = 4
 
                    else:
                        print("")
                        Continuar = input("Por Favor escoja(S/N): ")
 
                        if Continuar == "s" or Continuar == "S":
                            print("")
                            Ayuda_Opciones = float(input("Seleccionar Nº de Opción: "))
 
                        elif Continuar == "n" or Continuar == "N":
                            print("")
                            opciones = float(input("Seleccionar Nº de Opción: "))
                            Ayuda_Opciones = 4
 
                elif(Ayuda_Opciones==4):
                    print("")
                    Ayuda_Opciones = float(input("Seleccionar Nº de Opción: "))
 
        elif(opciones==21):
            borrarPantalla()
            Menu()
            opciones = float(input("Seleccionar Nº de Opción: "))
 
        elif(opciones==22):
            exit(0)
 
    while(opciones <1 or opciones >22 ):
        print("")
        print("Opción no Encontrada")
        print("")
        opciones = float(input("Seleccionar Nº de Opción: "))
 
Calculadora()
# Out:
#                      ÉÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍ»
#                      º                                  :: C A L C U L A D O R A ::                                      º
#                      ÌÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍ¹
#                      º                                                                                                   º
#                      º  1.- Sumar               2.- Restar             3.-Multiplicar              4.- Dividir           º
#                      º                                                                                                   º
#                      º  5.- Sacar Resto         6.- Sacar Potencia     7.- Sacar Raíz Cudrada      8.-  Sacar Seno       º
#                      º                                                                                                   º
# ...

# %%
5
